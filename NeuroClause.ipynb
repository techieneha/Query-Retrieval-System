# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached fastapi-0.116.1-py3-none-any.whl (95 kB)
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 13.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 20.8 MB/s eta 0:00:00
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# ...
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# ...
#    ---------------------------------------- 0.0/18.7 MB ? eta -:--:--
#    --- ------------------------------------ 1.8/18.7 MB 22.1 MB/s eta 0:00:01
#    -------- ------------------------------- 3.9/18.7 MB 9.4 MB/s eta 0:00:02
# ...

# %%
# !pip uninstall faiss-gpu -y 
# !pip install faiss-cpu
# Out:
# WARNING: Skipping faiss-gpu as it is not installed.
# ...
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/14.9 MB 21.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.9/14.9 MB 11.7 MB/s eta 0:00:01
#    ------------ --------------------------- 4.7/14.9 MB 9.0 MB/s eta 0:00:02
#    --------------- ------------------------ 5.8/14.9 MB 7.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.0/14.9 MB 6.9 MB/s eta 0:00:02
#    ------------------- -------------------- 7.1/14.9 MB 6.0 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.9 MB 5.4 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.9 MB 5.4 MB/s eta 0:00:02
#    --------------------- ------------------ 7.9/14.9 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 7.9/14.9 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 8.1/14.9 MB 3.7 MB/s eta 0:00:02
# ...

# %%
# !pip install nest_asyncio

# %%
import sys
import os

# Use raw string to fix path issue
project_path = os.path.abspath(r"C:\Users\SANSKRUTI\Downloads\Hackathon\neuroclause_project")

# Add to sys.path for module imports
if project_path not in sys.path:
    sys.path.append(project_path)

print("✅ Project path added to sys.path")
# Out:
# ✅ Project path added to sys.path

# %%
from dotenv import load_dotenv
import os

load_dotenv()

# Check if env is working
print("Model from .env:", os.getenv("OLLAMA_MODEL"))

# Test importing your module (even if blank)
from rag_pipeline import retriever, llm_reasoner, prompt_template

print("Modules imported successfully ✅")
# Out:
# Model from .env: mistral
# Modules imported successfully ✅

# %%
from rag_pipeline.retriever import load_pdf, embed_chunks, retrieve_with_rerank
from rag_pipeline.llm_reasoner import answer_with_llm
import asyncio

# Step 1: Load and parse PDF
url = "https://hackrx.blob.core.windows.net/assets/policy.pdf?sv=2023-01-03&st=2025-07-04T09%3A11%3A24Z&se=2027-07-05T09%3A11%3A00Z&sr=b&sp=r&sig=N4a9OU0w0QXO6AOIBiu4bpl7AXvEZogeT%2FjUHNO7HzQ%3D"  # Replace with actual PDF URL
docs = await load_pdf(url)

# Step 2: Embed chunks
db = embed_chunks(docs)

# Step 3: Retrieve relevant chunks for a question
question = "What is the waiting period for maternity benefits?"
top_chunks = await retrieve_with_rerank(question, db)

# Step 4: Use LLM to generate the answer
answer = answer_with_llm(question, top_chunks)
print("Answer:", answer)
# Out:
# C:\Users\SANSKRUTI\Downloads\Hackathon\neuroclause_project\rag_pipeline\retriever.py:48: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# Answer: <coroutine object answer_with_llm at 0x000001D4A998A320>

# %%
import nest_asyncio
import asyncio
nest_asyncio.apply()  # This is crucial in notebooks to avoid loop errors

from rag_pipeline.retriever import load_pdf, embed_chunks, retrieve_with_rerank
from rag_pipeline.llm_reasoner import answer_with_llm

# Step 1: Load your PDF
pdf_url = "https://hackrx.blob.core.windows.net/assets/policy.pdf?sv=2023-01-03&st=2025-07-04T09%3A11%3A24Z&se=2027-07-05T09%3A11%3A00Z&sr=b&sp=r&sig=N4a9OU0w0QXO6AOIBiu4bpl7AXvEZogeT%2FjUHNO7HzQ%3D"
docs = await load_pdf(pdf_url)

# Step 2: Embed chunks
vectorstore = embed_chunks(docs)

# Step 3: Retrieve top clauses
query = "Does the policy cover maternity benefits?"
top_docs = await retrieve_with_rerank(query, vectorstore)

# Step 4: Get the answer
answer = await answer_with_llm(query, top_docs)
print("Answer:", answer)
# Out:
# PDF loading failed:
# Traceback (most recent call last):
#   File "C:\Users\SANSKRUTI\anaconda3\Lib\site-packages\httpcore\_async\connection_pool.py", line 229, in handle_async_request
#     await self._close_connections(closing)
#   File "C:\Users\SANSKRUTI\anaconda3\Lib\site-packages\httpcore\_async\connection_pool.py", line 343, in _close_connections
#     with AsyncShieldCancellation():
#          ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\SANSKRUTI\anaconda3\Lib\site-packages\httpcore\_synchronization.py", line 214, in __enter__
#     self._anyio_shield.__enter__()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\SANSKRUTI\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 425, in __enter__
#     task_state = _task_states[host_task]
#                  ~~~~~~~~~~~~^^^^^^^^^^^
#   File "C:\Users\SANSKRUTI\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 686, in __getitem__
#     assert isinstance(key, asyncio.Task)
# ...

# %%
from dotenv import load_dotenv
import os
load_dotenv()
TEAM_TOKEN = os.getenv("TEAM_TOKEN", "hackrx_token")
print(TEAM_TOKEN)
# Out:
# Bearer 26e705335aa7bb76d19ff5dd0d81cba29d83b8b9b81dd4d6eae6c26b7b63d471

# %%
# !pip install pyngrok

# %%
# !ngrok config add-authtoken 30VIdmWHNNio0AtKar4ZT1UIg1e_mHhPCDXDpeDjH1eMzmpq
# Out:
# Authtoken saved to configuration file: C:\Users\SANSKRUTI\AppData\Local/ngrok/ngrok.yml

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8000)
print(f"🔗 Public URL: {public_url}")
# Out:
# 🔗 Public URL: NgrokTunnel: "https://f46d3f40107c.ngrok-free.app" -> "http://localhost:8000"
# t=2025-08-06T21:01:02+0530 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=a801b0a32d45 clientid=6a55a2f735dad41c31d8a9dc56ec0b36
# t=2025-08-06T21:01:03+0530 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=2d5fa3d23451 err="read tcp [2401:4900:1c45:2794:a185:abb2:2a23:4ea6]:63992->[2600:1f16:d83:1200::6e74:3]:443: wsarecv: An existing connection was forcibly closed by the remote host."
# t=2025-08-06T21:01:03+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# ...
